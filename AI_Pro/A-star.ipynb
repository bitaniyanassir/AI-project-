# %%
import heapq

# %%
heuristic = {
"addis ababa" : 26,"debre brhan" : 31,
"debre sina": 33,"ambo": 31,"debre markos":39,
"kemisse":40,"fnote selam":42,
"injibara":44,"metekel":59,"azezo":55,
"bahir dar":48,"lalibela":57,"dessie":44,
"woldia":50,"alamata":53,"sekota":59,
"mekele":58,"semera":42,"fanti rasu":49,
"kilbet rasu":55,"fanti rasu":49,"semera":42,
"gabi rasu":32,"gonder":56,"adwa":65,"adigrat":62,
"axum":66,"asmera":68,"shire":67,
"humera":65,"kartum":81,"metema":62,
"debark":60,"debre tabor":52,"adama":26,
"awash":27,"metehara":26,"chiro":31,
"dire dewa":31,"harer":35,"babile":37,
"jigijiga":40,"gobe":40,"sof oumer":45,
"dega habun":45,"kebri dehar":40,"woreder":46,
"gode":35,"dollo":18,"mokadisho":40,"liben":11,
"robe":22,"dodolla":19,"asasa":18,
"assella":22,"batu":19,"shashemene":16,
"hawassa":15,"dilla":12,"bule hora":8,
"yabello":6,"konso":9,"arba minch":13,
"wolayita sodo":17,"basketo":23,"dawro":23,
"jimma":33,"hossana":21,"worabe":22,
"butajera":21,"wolkite":25,"bedelle":40,
"nekemittie":39,"gimbi":43,"assosa":51,
"dembi dollo":49,"gore":46,"gambella":51,
"tepi":41,"mezan teferi":37,
"benchi maji":28,"juba":50,
"nairobi":22,"moyalle":0

}

# %%
 
graph = {
"addis ababa": {"debre brhan": 5 , "adama":3, "ambo": 5,"debre markos":13},
"ambo": {"nekemittie": 8, "wolkite": 6,"addis ababa":5},
"debre brhan":{"debre sina":2,"addis ababa":5},
"adama":{"addis ababa":3,"metehara":3,"batu":4,"assella":4},
"nekemittie": {"gimbi": 4, "bedelle":4,"ambo":8},
"wolkite": {"worabe": 5, "jimma": 8,"ambo": 6,"hossana":5,"butajera":4},
"bedelle":{"gore":6, "jimma":7 ,"nekemittie":4},
"gimbi": {"dembi dollo": 6 ,"nekemittie": 4,"assosa":8},
"jimma": {"bedelle":7, "bonga": 4,"wolkite": 8},
"worabe": {"hossana":2,"wolkite":5,"butajera": 2},
"gore":{"gambella": 5,"bedelle":6, "tepi":9},
"dembi dollo":{"assosa":12,"gambella":4,"gimbi":6},
"bonga":{"jimma":4,"tepi":8,"mezan teferi":4,"dawro":10},
"hossana":{"worabe":2,"shashemene":7,"wolayita sodo":4,"wolkite":5},
"butajera":{"batu":2,"worabe":2,"wolkite":4},
"gambella":{"gore": 5,"dembi dollo":4},
"assosa":{"dembi dollo":12,"gimbi":8},
"tepi":{"mezan teferi":4,"gore":9 ,"bonga":8},
"mezan teferi":{"bonga":4,"tepi":4},
"dawro":{"wolayita sodo":6,"bonga":10},
"shashemene":{"batu":3,"hawassa":1,"dodolla":3,"hossana":7,"worabe":6},
"wolayita sodo":{"dawro":6,"arba minch":4,"hossana":4},
"batu":{"adama":4,"butajera":2,"shashemene":3},
"metekel":{"bahir dar":11},
"basketo":{"arba minch":10,"benchi maji":5,"yabello":6},
"arba minch":{"wolayita sodo":4,"basketo":10,"konso":4},
"benchi maji":{"basketo":5,"juba":22},
"hawassa":{"dilla":3,"shashemene":1},
"dodolla":{"asasa":1,"shashemene":3,"robe":13},
"bahir dar":{"azezo":7,"metekel":11,"injibara":4,"fnote selam":6,"debre tabor":4},
"konso":{"yabello":3,"arba minch":4},
"juba":{"benchi maji":22},
"dilla":{"bule hora":4,"hawassa":3},
"asasa":{"dodolla":1,"assella":4},
"robe":{"gobe":18, "sof oumer":23,"liben":11,"dodolla":13},
"metehara":{"adama":3,"awash":1},
"assella":{"asasa":4,"adama":4},
"azezo":{"metema":7,"gonder":1,"bahir dar":7},
"injibara":{"fnote selam":2,"bahir dar":4},
"fnote selam":{"bahir dar":6,"injibara":2,"debre markos":3},
"yabello":{"moyalle":6,"konso":3,"bule hora":2},
"bule hora":{"dilla":4,"yabello":2},
"liben":{"robe":11,"moyalle":11},
"sof oumer":{"gobe":6,"robe":23,"gode":23},
"awash":{"chiro":4,"gobi rasu":5,"metehara":1},
"gobe":{"sof oumer":6,"babile":28,"robe":18},
"gonder":{"metema":7,"debark":4,"azezo":1,"humera":9, "debre tabor":6},
"metema":{"kartum":19,"azezo":7,"gonder":7},
"debre markos":{"debre sina":17,"fnote selam":3,"addis ababa":13},
"debre sina":{"kemisse":7,"debre markos":17,"debre brhan":2},
"moyalle":{"nairobi":22, "yabello":6,"liben":11,"dollo":18,"mokadisho":40},
"kebri dehar":{"dega habun":6,"woreder":6,"gode":5},
"chiro":{"awash":4,"dire dewa":8},
"gobi rasu":{"semera":10,"awash":5},
"dega habun":{"jigijiga":5,"kebri dehar":6},
"humera":{"shire":8,"kartum":21,"gonder":9},
"debark":{"gonder":4,"shire":7},
"kartum":{"metema":19,"humera":21},
"kemisse":{"dessie":4,"debre sina":7},
"gode":{"dollo":17, "mokadisho":22,"kebri dehar":5,"sof oumer":23},
"woreder":{"kebri dehar":6},
"dire dewa":{"chiro":8,"harer":4},
"semera":{"woldia":8,"gobi rasu":10,"alamata":11,"fanti rasu":7},
"jigijiga":{"babile":3,"dega habun":5},
"shire":{"humera":8,"debark":7,"axum":2},
"dessie":{"woldia":6,"kemisse":4},
"dollo":{"gode":17,"moyalle":18},
"mokadisho":{"gode":22,"moyalle":40},
"harer":{"babile":2,"dire dewa":4},
"woldia":{"dessie":6,"lalibela":7,"alamata":3,"semera":8},
"fanti rasu":{"kilbet rasu":6,"semera":7},
"alamata":{"sekota":6,"mekele":5,"woldia":3,"semera":11},
"babile":{"harer":2,"jigijiga":3,"gobe":28},
"axum":{"shire":2,"adwa":1,"asmera":5},
"lalibela":{"sekota":6,"debre tabor":8,"woldia":7},
"kilbet rasu":{"fanti rasu":6},
"sekota":{"lalibela":6,"alamata":6,"mekele":9},
"mekele":{"adwa":7,"adigrat":4,"sekota":9,"alamata":5},
"adwa":{"axum":1,"adigrat":4,"mekele":7},
"asmera":{"adigrat":6,"axum":5},
"debre tabor":{"lalibela":8,"bahir dar":4,"gonder":6},
"adigrat":{"asmera":6,"mekele":4,"adwa":4},
"nairobi":{"moyalle":22}

}

# %%
class StateNode:
    def __init__(self, state, g_cost, h_cost, parent=None):
        self.state = state
        self.g_cost = g_cost
        self.h_cost = h_cost
        self.parent = parent

    def __lt__(self, other):
        return (self.g_cost + self.h_cost) < (other.g_cost + other.h_cost)

# %%
def generate_path(graph, heuristic, initial_state, goal_state):
    open_list = []
    closed_list = set()

    # Create the initial node with g_cost = 0 and h_cost from the heuristic
    initial_node = StateNode(initial_state, 0, heuristic[initial_state])
    heapq.heappush(open_list, initial_node)

    while open_list:
        current_node = heapq.heappop(open_list)

        if current_node.state == goal_state:
            # Goal state reached, generate the path
            path = []
            while current_node:
                path.append(current_node.state)
                current_node = current_node.parent
            return path[::-1]  # Reverse the path to get from initial to goal

        closed_list.add(current_node.state)

        # Generate successors
        for successor_state, backward_cost in graph[current_node.state].items():
            if successor_state in closed_list:
                continue

            g_cost = current_node.g_cost + backward_cost
            h_cost = heuristic[successor_state]
            successor_node = StateNode(successor_state, g_cost, h_cost, current_node)

            # Check if the successor is already in the open list
            found = False
            for node in open_list:
                if node.state == successor_node.state:
                    found = True
                    if node.g_cost > successor_node.g_cost:
                        # Found a better path to the successor, update the node
                        open_list.remove(node)
                        heapq.heapify(open_list)
                        heapq.heappush(open_list, successor_node)
                    break

            if not found:
                # Add the successor to the open list
                heapq.heappush(open_list, successor_node)

    # No path found
    return initial_state = "addis ababa"
goal_state = "moyalle"

path = generate_path(graph, heuristic, initial_state, goal_state)
print("Path found:")
print(" -> ".join(path))
# Out:
#   Cell In[9], line 48
#     return initial_state = "addis ababa"
#                          ^
# SyntaxError: invalid syntax

# %%
def generate_path(graph, heuristic, initial_state, goal_state):
    open_list = []
    closed_list = set()

    # Create the initial node with g_cost = 0 and h_cost from the heuristic
    initial_node = StateNode(initial_state, 0, heuristic[initial_state])
    heapq.heappush(open_list, initial_node)

    while open_list:
        current_node = heapq.heappop(open_list)

        if current_node.state == goal_state:
            
            # Goal state reached, generate the path
            path = []
            # Initialize the cost to the g_cost of the goal node
            cost = current_node.g_cost  
            while current_node:
                path.append(current_node.state)
                current_node = current_node.parent
                # Reverse the path to get from initial to goal

            return path[::-1], cost  
        closed_list.add(current_node.state)

        # Generate successors
        for successor_state, backward_cost in graph[current_node.state].items():
            if successor_state in closed_list:
                continue

            g_cost = current_node.g_cost + backward_cost
            h_cost = heuristic[successor_state]
            successor_node = StateNode(successor_state, g_cost, h_cost, current_node)

            # Check if the successor is already in the open list
            found = False
            for node in open_list:
                if node.state == successor_node.state:
                    found = True
                    if node.g_cost > successor_node.g_cost:
                        # Found a better path to the successor, update the node
                        open_list.remove(node)
                        heapq.heapify(open_list)
                        heapq.heappush(open_list, successor_node)
                    break

            if not found:
                # Add the successor to the open list
                heapq.heappush(open_list, successor_node)

    # No path found
    return [], float('inf')

# Calculate the path and cost
initial_state = "addis ababa"
goal_state = "moyalle"

path, cost = generate_path(graph, heuristic, initial_state, goal_state)

# Print the path and cost
if path:
    print("Path found:")
    print(" -> ".join(path))
    print("Cost:", cost)
else:
    print("No path found.")
# Out:
# Path found:
# addis ababa -> adama -> batu -> shashemene -> hawassa -> dilla -> bule hora -> yabello -> moyalle
# Cost: 26
